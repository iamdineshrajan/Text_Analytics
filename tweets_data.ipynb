# %%
import pandas as pd
tweet_data=pd.read_csv(r"C:\Users\DELL\Downloads\tweet_data.csv",sep=',')

# %%
tweet_data
# Out:
#    sentiment                                               text  Unnamed: 2  \
# 0    neutral  Get Premium Tools and content , Upgrade to VIP...         NaN
# 1    neutral  RT @PinakiLaskar: #datascience job roles. How ...         NaN
# 2    neutral  RT @throttlefix: botnet fuerte\n https://t.co/...         NaN
# 3    neutral  RT @HaroldSinnott: 😱 #MachineLearning App Idea...         NaN
# 4    neutral  RT @PinakiLaskar: STEPS TO KICK OFF YOUR DATA ...         NaN
# ..       ...                                                ...         ...
# 95   neutral  RT @chidambara09: #cyber #fashion #market wher...         NaN
# 96  positive  RT @gp_pulipaka: AI Best: 180 #DataScience and...         NaN
# 97   neutral  RT @Little_Redstone: 📍 Scam Alert 📵 theft by 🤏...         NaN
# 98  positive  RT @ruben_arce_s: #AI Best:70+ All Machine Lea...         NaN
# 99   neutral  RT @chidambara09: #cyber #fashion #market wher...         NaN
#
#    Unnamed: 3 Unnamed: 4
# 0         NaN        NaN
# ...

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sentiment   100 non-null    object
#  1   text        100 non-null    object
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  1 non-null      object
#  4   Unnamed: 4  1 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 4.0+ KB

# %%
tweets=tweet_data[['sentiment','text']]

# %%
tweets
# Out:
#    sentiment                                               text
# 0    neutral  Get Premium Tools and content , Upgrade to VIP...
# 1    neutral  RT @PinakiLaskar: #datascience job roles. How ...
# 2    neutral  RT @throttlefix: botnet fuerte\n https://t.co/...
# 3    neutral  RT @HaroldSinnott: 😱 #MachineLearning App Idea...
# 4    neutral  RT @PinakiLaskar: STEPS TO KICK OFF YOUR DATA ...
# ..       ...                                                ...
# 95   neutral  RT @chidambara09: #cyber #fashion #market wher...
# 96  positive  RT @gp_pulipaka: AI Best: 180 #DataScience and...
# 97   neutral  RT @Little_Redstone: 📍 Scam Alert 📵 theft by 🤏...
# 98  positive  RT @ruben_arce_s: #AI Best:70+ All Machine Lea...
# 99   neutral  RT @chidambara09: #cyber #fashion #market wher...
#
# [100 rows x 2 columns]

# %%
import nltk

# %%
text=tweets['text']

# %%
text
# Out:
# 0     Get Premium Tools and content , Upgrade to VIP...
# 1     RT @PinakiLaskar: #datascience job roles. How ...
# 2     RT @throttlefix: botnet fuerte\n https://t.co/...
# 3     RT @HaroldSinnott: 😱 #MachineLearning App Idea...
# 4     RT @PinakiLaskar: STEPS TO KICK OFF YOUR DATA ...
#                             ...
# 95    RT @chidambara09: #cyber #fashion #market wher...
# 96    RT @gp_pulipaka: AI Best: 180 #DataScience and...
# 97    RT @Little_Redstone: 📍 Scam Alert 📵 theft by 🤏...
# 98    RT @ruben_arce_s: #AI Best:70+ All Machine Lea...
# 99    RT @chidambara09: #cyber #fashion #market wher...
# Name: text, Length: 100, dtype: object

# %%
text=' '.join(tweets['text'])

# %%
text
# Out:
# 'Get Premium Tools and content , Upgrade to VIP https://t.co/HatjFbJ4LX\\n\\n#bigdata \\n#ViVAtech2021\\n#DEVCommunity… https://t.co/3DkaMxpekL RT @PinakiLaskar: #datascience job roles. How to make money with your #programming skills\\n\\n#BigData #Analytics #DataScience #IoT #IIoT #RSt… RT @throttlefix: botnet fuerte\\n https://t.co/hFtuP0LaV9\\n\\n#bigdata \\n#ViVAtech2021\\n#DEVCommunity #teChnOlOgy #Programming #AI #iioT #100DaysO… RT @HaroldSinnott: 😱 #MachineLearning App Ideas 2021\\n\\nvia @ValueCoders\\nhttps://t.co/9FngS1ycMQ\\n\\n#AI #5G #Healthcare #SmartCity #FutureofWor… RT @PinakiLaskar: STEPS TO KICK OFF YOUR DATA SCIENCE LEARNING PATH\\n\\n#MachineLearning #BigData #Analytics #DataScience #IoT #IIoT #Python #… RT @PinakiLaskar: STEPS TO KICK OFF YOUR DATA SCIENCE LEARNING PATH\\n\\n#MachineLearning #BigData #Analytics #DataScience #IoT #IIoT #Python #… RT @BotPoetsSociety: Can you guess the #poem that is human and the one created by #MachineLearning ?\\n\\n #machinele
# ...

# %%
text=text.lower()

# %%
text=text.strip()

# %%
import string

# %%
t1="".join([word for word in text if word not in string.punctuation])

# %%
t1
# Out:
# 'get premium tools and content  upgrade to vip httpstcohatjfbj4lxnnbigdata nvivatech2021ndevcommunity… httpstco3dkamxpekl rt pinakilaskar datascience job roles how to make money with your programming skillsnnbigdata analytics datascience iot iiot rst… rt throttlefix botnet fuerten httpstcohftup0lav9nnbigdata nvivatech2021ndevcommunity technology programming ai iiot 100dayso… rt haroldsinnott 😱 machinelearning app ideas 2021nnvia valuecodersnhttpstco9fngs1ycmqnnai 5g healthcare smartcity futureofwor… rt pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python … rt pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python … rt botpoetssociety can you guess the poem that is human and the one created by machinelearning nn machinelearning datascience  arti… rt pinakilaskar best challenging coding websitesnnmachinelearning bigdata analytics datascience io
# ...

# %%
import re

# %%
t2=re.sub('[^a-zA-Z]',' ',t1)

# %%
t2
# Out:
# 'get premium tools and content  upgrade to vip httpstcohatjfbj lxnnbigdata nvivatech    ndevcommunity  httpstco dkamxpekl rt pinakilaskar datascience job roles how to make money with your programming skillsnnbigdata analytics datascience iot iiot rst  rt throttlefix botnet fuerten httpstcohftup lav nnbigdata nvivatech    ndevcommunity technology programming ai iiot    dayso  rt haroldsinnott   machinelearning app ideas     nnvia valuecodersnhttpstco fngs ycmqnnai  g healthcare smartcity futureofwor  rt pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python   rt pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python   rt botpoetssociety can you guess the poem that is human and the one created by machinelearning nn machinelearning datascience  arti  rt pinakilaskar best challenging coding websitesnnmachinelearning bigdata analytics datascience io
# ...

# %%
t2=re.sub('rt',' ',t2)

# %%
t2
# Out:
# 'get premium tools and content  upgrade to vip httpstcohatjfbj lxnnbigdata nvivatech    ndevcommunity  httpstco dkamxpekl   pinakilaskar datascience job roles how to make money with your programming skillsnnbigdata analytics datascience iot iiot rst    throttlefix botnet fue en httpstcohftup lav nnbigdata nvivatech    ndevcommunity technology programming ai iiot    dayso    haroldsinnott   machinelearning app ideas     nnvia valuecodersnhttpstco fngs ycmqnnai  g healthcare sma city futureofwor    pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python     pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python     botpoetssociety can you guess the poem that is human and the one created by machinelearning nn machinelearning datascience  a i    pinakilaskar best challenging coding websitesnnmachinelearning bigdata analytics datascience iot iiot rst
# ...

# %%
t2=t2.strip()

# %%
t2
# Out:
# 'get premium tools and content  upgrade to vip httpstcohatjfbj lxnnbigdata nvivatech    ndevcommunity  httpstco dkamxpekl   pinakilaskar datascience job roles how to make money with your programming skillsnnbigdata analytics datascience iot iiot rst    throttlefix botnet fue en httpstcohftup lav nnbigdata nvivatech    ndevcommunity technology programming ai iiot    dayso    haroldsinnott   machinelearning app ideas     nnvia valuecodersnhttpstco fngs ycmqnnai  g healthcare sma city futureofwor    pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python     pinakilaskar steps to kick off your data science learning pathnnmachinelearning bigdata analytics datascience iot iiot python     botpoetssociety can you guess the poem that is human and the one created by machinelearning nn machinelearning datascience  a i    pinakilaskar best challenging coding websitesnnmachinelearning bigdata analytics datascience iot iiot rst
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
token=word_tokenize(t2)

# %%
from nltk.corpus import stopwords

# %%
t3=set(stopwords.words('english'))

# %%
t4=[word for word in token if word not in t3]

# %%
t4
# Out:
# ['get',
#  'premium',
#  'tools',
#  'content',
#  'upgrade',
#  'vip',
#  'httpstcohatjfbj',
#  'lxnnbigdata',
#  'nvivatech',
#  'ndevcommunity',
#  'httpstco',
#  'dkamxpekl',
#  'pinakilaskar',
#  'datascience',
#  'job',
#  'roles',
#  'make',
#  'money',
#  'programming',
#  'skillsnnbigdata',
#  'analytics',
#  'datascience',
#  'iot',
#  'iiot',
#  'rst',
#  'throttlefix',
#  'botnet',
#  'fue',
#  'en',
#  'httpstcohftup',
#  'lav',
#  'nnbigdata',
#  'nvivatech',
#  'ndevcommunity',
#  'technology',
#  'programming',
#  'ai',
#  'iiot',
#  'dayso',
#  'haroldsinnott',
#  'machinelearning',
#  'app',
#  'ideas',
#  'nnvia',
#  'valuecodersnhttpstco',
#  'fngs',
#  'ycmqnnai',
#  'g',
#  'healthcare',
#  'sma',
#  'city',
#  'futureofwor',
#  'pinakilaskar',
#  'steps',
#  'kick',
#  'data',
#  'science',
#  'learning',
#  'pathnnmachinelearning',
#  'bigdata',
#  'analytics',
#  'datascience',
#  'iot',
#  'iiot',
#  'python',
#  'pinakilaskar',
#  'steps',
#  'kick',
# ...

# %%
from nltk.stem import WordNetLemmatizer

# %%
t5=WordNetLemmatizer()

# %%
t6=[]

# %%
for word in t4:
    t6.append(t5.lemmatize(word))
    print(t5.lemmatize(word))
# Out:
# get
# premium
# tool
# content
# upgrade
# vip
# httpstcohatjfbj
# lxnnbigdata
# nvivatech
# ndevcommunity
# httpstco
# dkamxpekl
# pinakilaskar
# datascience
# job
# role
# make
# money
# programming
# skillsnnbigdata
# analytics
# datascience
# iot
# iiot
# rst
# throttlefix
# botnet
# fue
# en
# httpstcohftup
# lav
# nnbigdata
# nvivatech
# ndevcommunity
# technology
# programming
# ai
# iiot
# dayso
# haroldsinnott
# machinelearning
# app
# idea
# nnvia
# valuecodersnhttpstco
# fngs
# ycmqnnai
# g
# healthcare
# sma
# city
# futureofwor
# pinakilaskar
# step
# kick
# data
# science
# learning
# pathnnmachinelearning
# bigdata
# analytics
# datascience
# iot
# iiot
# python
# pinakilaskar
# step
# kick
# data
# science
# learning
# pathnnmachinelearning
# bigdata
# analytics
# datascience
# iot
# iiot
# python
# botpoetssociety
# guess
# poem
# human
# one
# created
# machinelearning
# nn
# machinelearning
# datascience
# pinakilaskar
# best
# challenging
# coding
# ...

# %%
from nltk.probability import FreqDist

# %%
t7=FreqDist(t6)

# %%
t7.tabulate()
t7
# Out:
#                                         datascience                                                  ai                                           analytics                                             bigdata                                     machinelearning                                                iiot                                                 iot                                              python                                            learning                                              rstats                                                data                                                best                                        pinakilaskar                                           algorithm                                          javascript                                             machine                                         iainljbrown                                           nnbigdata                                              market           
# ...

# %%
conda install -c conda-forge pandas-profiling
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\DR\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa244fe_3         3.1 MB  conda-forge
#     pandas-profiling-1.4.1     |                0          40 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-profiling   conda-forge/win-64::pandas-profiling-1.4.1-0
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2021.10.8-py38haa9~ --> conda-forge::certifi-2021.10.8-py38haa244fe_1
#   conda              pkgs/main::conda-4.10.3-py38haa95532_0 --> conda-forge::conda-4.10.3-py38haa244fe_3
#
# ...

# %%
conda install -c conda-forge pandasgui

# %%
conda install -c conda-forge dtale
